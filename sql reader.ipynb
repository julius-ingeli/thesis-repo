# %%
import pandas as pd
import mysql.connector as sqlc
import plotly.express as px

# %%
mydb = sqlc.connect(
    host = "localhost",
    user = "root",
    password = "REDACTED",
    database='mydb')

# %%
Tquery = "SELECT * from temps;"

Tdf = pd.read_sql(Tquery,mydb)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
Tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27305 entries, 0 to 27304
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Number       27305 non-null  int64
#  1   Timestamp    27305 non-null  datetime64[ns]
#  2   Status       27305 non-null  object
#  3   Temperature  27305 non-null  float64
#  4   Humidity     27305 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
Tdf.shape
# Out:
# (27305, 5)

# %%
Tdf
# Out:
#        Number           Timestamp     Status  Temperature  Humidity
# 0           1 2022-06-01 14:09:05  DHT11,OK!         23.6      50.0
# 1           2 2022-06-01 14:09:07  DHT11,OK!         23.5      46.0
# 2           3 2022-06-01 14:09:11  DHT11,OK!         23.5      49.0
# 3           4 2022-06-01 14:09:13  DHT11,OK!         23.5      51.0
# 4           5 2022-06-01 14:09:17  DHT11,OK!         23.5      49.0
# ...       ...                 ...        ...          ...       ...
# 27300   25920 2022-06-02 20:32:53  DHT11,OK!         21.2      60.0
# 27301   25921 2022-06-02 20:32:56  DHT11,OK!         21.2      60.0
# 27302   25922 2022-06-02 20:32:58  DHT11,OK!         21.1      59.0
# 27303   25923 2022-06-02 20:33:01  DHT11,OK!         21.2      59.0
# 27304   25924 2022-06-02 20:33:03  DHT11,OK!         21.1      59.0
#
# [27305 rows x 5 columns]

# %%
fig0 = px.pie(Tdf,values="Number",names="Status", title="Status of readings.")
fig0.show()

# %%
fig1 = px.line(Tdf,"Timestamp","Temperature", labels={"Timestamp": "Time", "Temperature" : "Temperature(°C)"}, title="Temperature in room")
fig1.update_layout(yaxis_range=[15,30])
fig1.show()

# %%
fig1 = px.line(Tdf,"Timestamp","Humidity", labels={"Timestamp": "Time", "Humidity" : "Humidity(%)"}, title="Humidity in room",color_discrete_sequence=["red"])
fig1.update_layout(yaxis_range=[0,100])
fig1.show()

# %%
TdfML = Tdf["Temperature"]
# %store TdfML
HdfMl = Tdf["Humidity"]
# %store HdfMl
# Out:
# Stored 'TdfML' (Series)
# Stored 'HdfMl' (Series)
